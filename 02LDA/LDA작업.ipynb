# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonandmoon/GS_team/blob/main/LDA%EC%9E%91%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/gs건설 프로젝트/GS_news2108_2310.csv')
df
# Out:
#              date                      Title  \
# 0      2021-08-01          분양 동향 계양 전국 가구 분양
# 1      2021-08-01  플랫 고도 악어 메타 버스 알고리즘 개발 추진
# 2      2021-08-01                계양 가구 분양 예정
# 3      2021-08-01            가점 마련 가능 추첨제 분양
# 4      2021-08-01          도시 수도 지방 청약 시장 풍성
# ...           ...                        ...
# 18399  2023-10-29            노량진 송파 알짜 수주 치열
# 18400  2023-10-29         분양 캘린더 분상 적용 가구 분양
# 18401  2023-10-29               변호사 신임 대표 선출
# 18402  2023-10-29                        아파트
# 18403  2023-10-29                         대표
#
#                                                  Content  \
# 0      견본 주택 전국 개관 예정 분양 일정 사진 부동산 이달 전국 가구 달하 신규 분양 ...
# 1      악어 서비스 대표 이미지 아이 서비스 악어 첨단 기술 활용 서비스 고도 방문 선생 ...
# 2      분양 캘린더 전국 가구 분양 전국 가구 분양 예정 부동산 따르 전국 단지 가구 사전...
# 3      오전 부동산 중개 업소 월세 매물 정보 사진 올해 하반기 도시 사전 청약 분양 관심...
# 4      규모 주목 도시 사전 청약 열기 수도 지방 청약 시장 부동산 전문 리서치 업체 리얼...
# ...                                                  ...
# ...

# %%
df2 = df[['date','tokens']]
df2
# Out:
#              date                                             tokens
# 0      2021-08-01  견본 주택 전국 개관 예정 분양 일정 사진 부동산 이달 전국 가구 달하 신규 분양 ...
# 1      2021-08-01  악어 서비스 이미지 아이 서비스 악어 첨단 기술 활용 서비스 고도 방문 선생 애플리...
# 2      2021-08-01  분양 캘린더 전국 가구 분양 전국 가구 분양 예정 부동산 전국 단지 가구 사전 청약...
# 3      2021-08-01  오전 부동산 중개 업소 월세 매물 정보 사진 하반기 도시 사전 청약 분양 관심 커지...
# 4      2021-08-01  규모 주목 도시 사전 청약 열기 수도 지방 청약 시장 부동산 전문 리서치 업체 리얼...
# ...           ...                                                ...
# 18399  2023-10-29  연말 개발 재건축 입찰 전쟁 송파 가락 관심 노량진 구역 파전 단독 입찰 유력 주택...
# 18400  2023-10-29  단지 가구 공급 모델 의왕 관동 탄신 도시 파크 투시도 사진 주택 경제 부동산 전국...
# 18401  2023-10-29  신임 대표 임기 시작 변호사 공식 홈페이지 갈무리 뉴스 변호사 대표 선출 구성원 회...
# 18402  2023-10-29  연말 선정 돌입 집값 고공 행진 제한 강변 재건축 물밑 경쟁 조합 설립 층수 상향 ...
# 18403  2023-10-29  한화 전문 변호사 사진 임기 신임 업무 집행 대표 변호사 선출 임기 내년 변호사 대...
#
# [18404 rows x 2 columns]

# %% [markdown]
# ## LDA 작업

# %%
from gensim import corpora, models
from pprint import pprint

df2['tokens'] = df2['tokens'].fillna('')
df2['tokens'] = df2['tokens'].astype(str)
documents = df2['tokens'].values.tolist()
documents

# %%
tokenized_documents = [str(doc).split() for doc in documents]
tokenized_documents

# %%
dictionary = corpora.Dictionary(tokenized_documents)
corpus = [dictionary.doc2bow(doc) for doc in tokenized_documents]
corpus

# %%
num_topics = 15  # 주제의 수를 지정
lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)
lda_model

# %%
# 주제 및 주제 단어 출력
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.040*"사업" + 0.029*"구역" + 0.026*"조합" + 0.025*"정비" + 0.024*"재건축"')
# (1, '0.024*"사업" + 0.019*"개발" + 0.017*"항공" + 0.015*"참여" + 0.013*"도시"')
# (2, '0.024*"시장" + 0.014*"상승" + 0.014*"부동산" + 0.012*"투자" + 0.011*"금리"')
# (3, '0.024*"안전" + 0.023*"의원" + 0.020*"현장" + 0.017*"국민" + 0.014*"국회"')
# (4, '0.063*"영업" + 0.037*"분기" + 0.036*"누락" + 0.031*"이익" + 0.031*"사업"')
# (5, '0.059*"건설" + 0.038*"기업" + 0.036*"평가" + 0.029*"건설사" + 0.024*"업체"')
# (6, '0.024*"그룹" + 0.020*"경영" + 0.019*"회장" + 0.019*"사업" + 0.019*"대표"')
# (7, '0.018*"주택" + 0.015*"모듈러" + 0.015*"기술" + 0.015*"서비스" + 0.014*"아파트"')
# (8, '0.028*"규모" + 0.020*"지분" + 0.019*"투자" + 0.017*"공시" + 0.017*"결정"')
# (9, '0.035*"아파트" + 0.026*"사고" + 0.021*"공사" + 0.020*"국토" + 0.018*"붕괴"')
# (10, '0.024*"기술" + 0.018*"사업" + 0.018*"산업" + 0.016*"생산" + 0.014*"배터리"')
# (11, '0.030*"가구" + 0.021*"시설" + 0.015*"청약" + 0.015*"전용" + 0.014*"주택"')
# (12, '0.039*"가구" + 0.034*"분양" + 0.024*"단지" + 0.024*"예정" + 0.023*"아파트"')
# ...

# %%
df2['dominant_topic'] = None
df2['dominant_topic_probability'] = None
df2
# Out:
#              date                                             tokens  \
# 0      2021-08-01  견본 주택 전국 개관 예정 분양 일정 사진 부동산 이달 전국 가구 달하 신규 분양 ...
# 1      2021-08-01  악어 서비스 이미지 아이 서비스 악어 첨단 기술 활용 서비스 고도 방문 선생 애플리...
# 2      2021-08-01  분양 캘린더 전국 가구 분양 전국 가구 분양 예정 부동산 전국 단지 가구 사전 청약...
# 3      2021-08-01  오전 부동산 중개 업소 월세 매물 정보 사진 하반기 도시 사전 청약 분양 관심 커지...
# 4      2021-08-01  규모 주목 도시 사전 청약 열기 수도 지방 청약 시장 부동산 전문 리서치 업체 리얼...
# ...           ...                                                ...
# 18399  2023-10-29  연말 개발 재건축 입찰 전쟁 송파 가락 관심 노량진 구역 파전 단독 입찰 유력 주택...
# 18400  2023-10-29  단지 가구 공급 모델 의왕 관동 탄신 도시 파크 투시도 사진 주택 경제 부동산 전국...
# 18401  2023-10-29  신임 대표 임기 시작 변호사 공식 홈페이지 갈무리 뉴스 변호사 대표 선출 구성원 회...
# 18402  2023-10-29  연말 선정 돌입 집값 고공 행진 제한 강변 재건축 물밑 경쟁 조합 설립 층수 상향 ...
# 18403  2023-10-29  한화 전문 변호사 사진 임기 신임 업무 집행 대표 변호사 선출 임기 내년 변호사 대...
#
#       dominant_topic dominant_topic_probability
# 0               None                       None
# ...

# %%
for i, row in df2.iterrows():
    preprocessed_doc = [w for w in row['tokens'].split(' ') if len(w) > 1]
    bow = dictionary.doc2bow(preprocessed_doc)
    topic_info = lda_model[bow]
    # 지배적인 주제를 선택할 때 확률이 가장 높은 주제를 선택
    dominant_topic = max(topic_info, key=lambda x: x[1])
    df2.at[i, 'dominant_topic'] = dominant_topic[0]
    df2.at[i, 'dominant_topic_probability'] = dominant_topic[1]

# %%
df2
# Out:
#              date                                             tokens  \
# 0      2021-08-01  견본 주택 전국 개관 예정 분양 일정 사진 부동산 이달 전국 가구 달하 신규 분양 ...
# 1      2021-08-01  악어 서비스 이미지 아이 서비스 악어 첨단 기술 활용 서비스 고도 방문 선생 애플리...
# 2      2021-08-01  분양 캘린더 전국 가구 분양 전국 가구 분양 예정 부동산 전국 단지 가구 사전 청약...
# 3      2021-08-01  오전 부동산 중개 업소 월세 매물 정보 사진 하반기 도시 사전 청약 분양 관심 커지...
# 4      2021-08-01  규모 주목 도시 사전 청약 열기 수도 지방 청약 시장 부동산 전문 리서치 업체 리얼...
# ...           ...                                                ...
# 18399  2023-10-29  연말 개발 재건축 입찰 전쟁 송파 가락 관심 노량진 구역 파전 단독 입찰 유력 주택...
# 18400  2023-10-29  단지 가구 공급 모델 의왕 관동 탄신 도시 파크 투시도 사진 주택 경제 부동산 전국...
# 18401  2023-10-29  신임 대표 임기 시작 변호사 공식 홈페이지 갈무리 뉴스 변호사 대표 선출 구성원 회...
# 18402  2023-10-29  연말 선정 돌입 집값 고공 행진 제한 강변 재건축 물밑 경쟁 조합 설립 층수 상향 ...
# 18403  2023-10-29  한화 전문 변호사 사진 임기 신임 업무 집행 대표 변호사 선출 임기 내년 변호사 대...
#
#       dominant_topic dominant_topic_probability
# 0                 12                   0.784399
# ...

# %% [markdown]
# ## 시각화

# %%
# !pip install pyLDAvis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 68.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 23.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# ...

# %%
import pyLDAvis.gensim
import gensim
import pyLDAvis
from pprint import pprint

# %%
# pyLDAvis 시각화
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False)  # sort_topics 매개변수를 비활성화
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4681321654402474401470606502" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
pip install pandas==1.5.3
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 19.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.2
#     Uninstalling pandas-2.1.2:
#       Successfully uninstalled pandas-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...
